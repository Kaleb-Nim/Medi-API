# %%
from dotenv import load_dotenv
import pinecone
import openai
import os
import json
from time import time 
import tqdm
# Typing
from typing import List, Dict, Any, Optional, Union, Tuple

from langchain.embeddings import OpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pinecone.index import Index
from pinecone.index import UpsertResponse

# Data processing stuff
import pandas as pd

from PineconeUtils.Indexer import Indexer,DataEmbedding

# %%
load_dotenv()
PINECONE_API_KEY,PINECONE_ENVIRONMENT,INDEX_NAME = os.getenv("PINECONE_API_KEY"),os.getenv("PINECONE_ENVIRONMENT"),os.getenv("PINECONE_INDEX_NAME")
print('PINECONE_API_KEY,PINECONE_ENVIRONMENT,INDEX_NAME: ', PINECONE_API_KEY,PINECONE_ENVIRONMENT,INDEX_NAME)
# Out:
# PINECONE_API_KEY,PINECONE_ENVIRONMENT,INDEX_NAME:  3efa3801-3d5d-4f24-8259-1d9dc446478d gcp-starter namchat

# %% [markdown]
# # Load the Json file in

# %%
# Load json file 
with open('./data/qna_01-11-2023.json',encoding="utf-8") as f:
    inserts = json.load(f)

# Extract as list of dicts, 
"""
Example:
[{
    questions:[str],
    answer: str,
}]
"""

def extract_qna_json(json_file_path:str) ->list[dict]:
    with open(json_file_path,encoding="utf-8") as f:
        data = json.load(f)

    final = []

    question_list = data['qnas']
    for question in question_list:
        final.append({
            'questions':question['data']['questions']['en'],
            'answers':question['data']['answers']['en']
        })
    return final

qn_ans_list = extract_qna_json('./data/qna_01-11-2023.json')
qn_ans_list
# Out:
# [{'questions': ['What is Advance Care Planning (ACP)? ',
#    'What is the programme that helps me plan out future health and personal care?',
#    'Which programme helps me plan for future medical care?',
#    'Advance Care Planning (ACP)'],
#   'answers': ["- Advance Care Planning (ACP) is the process of planning for future health and personal care your loved one's ACP document tells you and doctors about the treatment options your loved one prefers, should they be unable to communicate their wishes.  \n- This is about creating a plan that can be used if your loved one is unable to make their own decisions. They can also change it at any time, as long as your loved one retains their mental capacity.\n- Your loved one can do an ACP if they have mental capacity. Mental capacity refers to a person’s ability to make a decision for themselves and is specific to the particular decision that needs to be made. \n- A person is deemed to have mental capacity, when they can still:\n     • Understand the facts involved in making the decision.\n     • Retain the information used in decision making.\n     • Use the information to weigh up the pros, cons, and consequences of their choice; and communicate the decision they have made."]},
#  {'questions': ['How can I take care of myself while caring for my loved one with dementia?',
#    'How can a caregiver take care of himself or herself while caring for dementia patient?',
#    'What should a caregiver do to better take care of ownself while caring for the loved one with dementia?',
#    'Self-help or self-care for caregivers who are caring for a patient with dementia',
#    'Tips and guides for caregiver self-care',
#    'What can a caregiver do to better take care of himself or herself while caring for the patient?',
#    'Self-care tips for caregivers',
#    'What should caregivers do if finding it difficult to spare time or effort for other matters',
#    'Self-help tips',
#    'What should a caregiver do to stay healthy while caring for the loved one with dementia?'],
#   'answers': ['Ask for help\n• Tell friends and family how you\'re feeling: be honest about how you\'re feeling and what the situation is, having a conversation about how to move forward will be beneficial\n• Spread the responsibility, if possible: divide tasks up to other family members so that they can all pitch in. Tasks can include medical responsibilities, finances, bills, groceries, chores, etc. \n• Don’t be afraid to accept help: others feel good about themselves when helping others, so don\'t feel guilty\n• Look into respite care if necessary \n\nHear from caregiver Paul on his journey to care for his mother who lives with dementia:\n\n<a href="https://m.facebook.com/watch/?v=1006218726996702&_rdr" target="_blank">Click for detail</a>\n\nRespite is important for caregivers and you may need to access this unexpectedly. Planning ahead for respite care will help you to better care for yourself and your loved ones. You can pre-enrol for respite care ahead of time under the Go Respite pilot programme by AIC\n\n<a href="https://www.aic.sg/caregiving/go-respite-pilot" target="_blank">Click for detail</a>\n\nHere is a list of participating service providers for Go Respite Programme:\n<a href="https://www.aic.sg/caregiving/Documents/Go%20Respite%20-%20Participating%20Centres%20and%20NHs%20(for%20SSP).pdf\n" target="_blank">Click for detail</a>\n\nYou can listen and follow this relaxation exercise which may help to reduce your stress and anxiety\n\nYou can also refer to some of the worksheets in the CareBuddy app that may help to address your anxiety and depression\n']},
#  {'questions': ['How to apply for CARA?',
#    'How to register for CARA?',
#    'How to join CARA?',
#    'Who are eligible to join CARA?',
#    'How to apply for CARA membership?',
#    'What is CARA?',
#    'What is CARA membership?',
#    'How long is the CARA application process?',
#    'How to register for CARA membership?',
#    'What will I receive if I apply for CARA?',
#    'What CARA?'],
#   'answers': ['- A CARA membership is eligible to Singapore residents who are either a) living with dementia, or b) is a caregiver of a person living with dementia.  \n- Members living with dementia will receive the physical CARA card and e-card in the app. Caregivers will only receive the e-card.\n- To apply, download the CARA SG mobile application from Google Playstore or Apple Appstore and you will be guided through the sign-up process (filling out caregiver and person living with dementia details). \n- The application will then be processed and approved members will receive notification and updates via the CARA SG Mobile App about the outcome of their registration (within 7 working days). \n- Visit <a href="https://cara.sg/" target="_blank">Click for detail</a>for more information.']},
#  {'questions': ['What services does Dementia Singapore (DSG) provide?',
#    'What services does DSG provide',
#    'What are DSG services',
#    'What can DSG provide',
#    'Services of Dementia Singapore',
#    'Services of DSG',
#    'What can DSG do',
#    'What are the available services of DSG',
#    'Dementia Singapore available services or support',
#    'DSG provide what services'],
#   'answers': ['1. <b> Caregiver support service: </b> provides services to support and empower caregivers such as supporting them in self-care, health and wellness activities, stress management, peer support, future planning and emotional support.\n2. <b> Dementia daycare: </b> New Horizon Centres - provides day care services for people with dementia.\n3. <b> Family of Wisdom programme: </b> a weekly 3-hour enrichment programme to provide continuum of community care for persons with dementia who have completed sessional therapy outpatient programmes and discharged for community care.\n4. <b> Dementia social club: </b> empowers caregivers, persons with dementia and, those with young onset dementia to participate in purposeful and meaningful activities with loved ones. \n5. <b> Voices for Hope: </b> empowerment programme that aims to bring persons with dementia and their care partners on a self-advocacy journey.\n6. <b> Arts and dementia programme: </b> provides a safe public space for inspiration and meaningful inspiration and meaningful engagement to persons living with dementia and their care partners.\n7. <b> CARA membership: </b> a lifestyle and community platform on a mobile application that provides assurance through its unique identifier and offers tailored rewards for those impacted by dementia and aims to drive social acceptance.                                                                                                                                                              ']},
#  {'questions': ['Does your loved one with dementia often confuse daytime and night time?',
#    'Unable to have a sense of time',
#    'Confusing day and night'],
#   'answers': ['Try to create routines\n• People with dementia often become disoriented in time. This may be the result of confusion caused by changes in the brain, memory loss or perhaps due to difficulties recognising people and objects. \n• The “internal clock”, which enables people to know roughly when it is time to eat or sleep also tends to be disrupted. For the person with dementia, the main problem is not so much being unaware of what time it is or recognising a place and finding different rooms, but more the anxiety that this causes.\n• The knowledge that it is midday is not particularly important, but the possibility of having missed lunch, a favourite television programme or the fear of having been deserted might well be.\n• For example, they may seem anxious about whether it is 10 o’clock yet (the time at which the bus arrives for the day centre). In this case, it would be better to reassure them that you will make sure they do not miss the bus, rather than simply stating that it is only a quarter past nine.\nHow to create routines\n• You may find that the person with dementia does not really understand what you mean by “at five o’clock” or “in ten minutes”. But, there are other ways to express the passing of time. It has been found that some people with dementia can make sense of an old fashioned hourglass, even if it is not something they are used to.\n• Try to create routines. Structure the time with meaningful routine or engagement. As it becomes increasingly difficult for the person with dementia to keep track of time, it helps if you stick to a regular routine with several events to break up the day, thereby providing some kind of structure.\n• If there are enough events occurring throughout the day, there are more opportunities to realise roughly what time of the day it is and even what is going on.\n• A regular routine prevents the day seeming like a continuous series of surprise events and this may reduce anxiety. One idea is to write down a plan of the day’s routine at breakfast time with the person with dementia. You could then go over it again at lunchtime. Otherwise, you could stick to more or less the same basic routine every day, without actually writing it down.']},
#  {'questions': ['Does your loved one with dementia hold food in their mouth or not swallow their food?',
#    'dementia holding food and not swallowing',
#    'dementia food holding'],
#   'answers': ['Has this been evaluated by a doctor? If not, kindly consult your doctor first\nGive reminders:\n• Offer food that does not require much chewing\n• Give verbal reminders to swallow \n• Present an empty spoon near or in their mouth to prompt them to perform the swallowing action again']},
#  {'questions': ['How to reduce the risk of getting dementia?',
#    'Reduce the risk of getting dementia',
#    'How to avoid dementia',
#    'What are the causes of dementia',
#    'What is the cause of dementia',
#    'What are the risks that will cause dementia',
#    'How to prevent dementia',
#    'How to prevent getting dementia',
#    'What can cause dementia',
#    'Why does one get dementia',
#    'Will I get dementia',
#    'What are the risk factors of dementia'],
#   'answers': ['While there is no certain way to prevent dementia, adopting a healthy lifestyle and being aware of risk factors can minimise the chances of developing dementia.\nYou can learn from fellow caregiver on his journey and find out how to reduce the risk of dementia via preventive activities:\n <a href="https://www.youtube.com/watch?app=desktop&v=1QCRSvATEDQ" target="_blank">Click for detail</a>\nRisk factors \n • Physical inactivity \n • High blood pressure \n • High blood cholesterol \n • Diabetes melitius \n • Excessive alcohol consumption \n • Smoking \n • Mid-life obesity \n • Head trauma \nFactors that lower risk of dementia \n • Being physically active - \nStanding activity that trains your cognition and physical functions to reduce the risk of dementia:\n<a href=" https://www.youtube.com/watch?v=S4bKzy1TbSQ&t=56s" target="_blank">Click for detail</a>\n • Seated activity that trains your cognition and motor skills to reduce the risk of dementia:\n <a href="https://www.youtube.com/watch?v=K7sVXsCks_4" target="_blank">Click for detail</a>\n • Keeping blood pressure at a healthy level \n • Good cardiovascular health \n • Monitoring blood glucose (if diabetic) \n • Eating a balanced diet - diet rich in fruits, vegetables and omega-3 fatty acids – commonly found in certain fish and nuts – may promote overall health and offset or delay the setting in of dementia.\n • Quitting smoking \n • Going for regular health screening \n • Refraining from heavy alcohol intake \nBeing socially engaged - To stay connected, you may head to your nearby community centres or senior activity centres available in the community.\nEngaging in cognitive training or brain activity - Keep your mind active. Mentally stimulating activities, such as puzzles, Sudoku and other word games serve as cognitive training that may offset or delay the setting in of dementia. Visit the following websites to enjoy some of these brain games or Silver Activities:\n<a href="www.silveractivities.com" target="_blank">Click for detail</a>\n<a href="www.lumosity.com" target="_blank">Click for detail</a>\nYou may consider taking the Brief Dementia Test [LINK that directs them to the Brief Dementia Test page on CB] through CareBuddy for a preliminary assessment on whether you might have dementia or not.\n']},
#  {'questions': ['Does your loved one have difficulty managing their medication?',
#    'Managing medication',
#    'manage medication',
#    'medication management'],
#   'answers': ['While it may be easier to manage their own medication in the early stages of dementia, it becomes more difficult to do so as their condition progresses. \nHere are some tips:\n• Use pill boxes - You can watch a video by The Ministry of Health on how to pack a pill box <a href="https://www.youtube.com/watch?v=ukwvJWGzVYc " target="_blank">Click for detail</a>\n• Set reminders \n• Use a timetable\nFor additional resources you can also access the Dementia Hub website. <a href="https://www.dementiahub.sg/living-well-with-dementia/tips-to-manage-dementia-medications/" target="_blank">Click for detail</a>']},
#  {'questions': ['What are the fees for diagnosis/assessment? ',
#    'What are the fees for diagnosis of dementia',
#    'What are the fees for assessment of dementia',
#    'How much will it cost for diagnose of dementia',
#    'How much will it cost for an assessment of dementia',
#    'How much are the fees for diagnosing dementia',
#    'How much to assess dementia',
#    'How much is the charge to get a dementia assessment',
#    'How much money is needed to assess dementia',
#    'How is the cost like for diagnosis or assessment of dementia',
#    'What is the cost for diagnosis or assessment of dementia'],
#   'answers': ['While you might assume that your senior has dementia and treat them accordingly, it is still important to get a diagnosis recognised by a practicing doctor. An official diagnosis can be obtained through referral to the geriatric department of any hospital. The costs of diagnosis would include visits to a specialist as well as the costs of running diagnostic tests. These tests can include brain scans, a psychiatric evaluation, laboratory tests of blood or spinal fluid, and a neurological evaluation. Nevertheless, early diagnosis has been shown to be able to cut the costs of dementia care by nearly 30 per cent as it can reduce spending on unnecessary tests and treatments.\nSome potential costs for various tests:\n1. Cost of brain scan: $375\n2. Cost of psychiatric evaluation: $124-$188 per hour\n3. Cost of neurological evaluation: $180-$200 per session\n4. Cost of laboratory tests: $400 for positron emission tomography (PET)']},
#  {'questions': ['What are the behavioural symptoms of dementia?',
#    'behavioural symptoms of dementia',
#    'dementia behavioural symptoms',
#    'dementia behavioural'],
#   'answers': ['Some of the behavioural symptoms or behaviours that your loved one may display could be:\n1) physically aggressive symptoms like hitting, kicking, throwing objects, etc\n2) physically non-aggressive symptoms like being restless, fidgety, repetitious movements, etc\n3) verbally aggressive and non-aggressive symptoms like making verbal sexual advances, making strange noises, etc\n4) mood changes\n5) hallucination/delusions\n6) being disoriented in time or space\n7) refusing or avoiding care ']},
#  {'questions': ['Does your loved one with dementia have weakness in the legs? ',
#    'Does your loved one with dementia  get tired after walking for a short period of time? ',
#    'Do your loved one with dementia  take a break every couple of steps or need to sit? ',
#    'Does your loved one with dementia  not get out of bed or move very often? ',
#    'Weakness in legs',
#    'Getting tired faster',
#    'Taking frequent breaks while walking',
#    'Not wanting to move or leave the bed'],
#   'answers': ['Has this been evaluated by a doctor? If not, kindly consult your doctor first.\nHome modifications for your loved one with dementia that who are unsteady on their feet \nHome modifications for motor deficiencies:\n        •  Add grab bars, especially in wet and slippery areas, e.g. bathroom\n        •  Use non-slip mats or apply non-slip treatments on floors of wet and slippery areas, e.g. bathroom and toilet\n        •  Remove any rugs and wires on the floor\nMove switches to an accessible level\nIf you stay in a multi-storey house, move your loved one to a room on the ground floor\nHome Modifications for Vision Deficiencies:\n        •  Use different colours for the floor, walls, and doors to help a person living with dementia distinguish between the two\n        •  Use contrasting colours for different surfaces/objects. This will help them tell the difference between items and spaces and is especially useful for those living with visual-spatial impairment.\n        •  Highlight steps and stairs with fluorescent tape for better visibility at night\nComplex Modifications:\nWiden doorways for easy access into rooms, if your care recipient uses a wheelchair\n        •  Install ramps\n        •  Remove walls\nYou can watch this video on how to design a dementia-friendly home\n <a href="https://qanvast.com/sg/articles/how-to-design-a-dementia-friendly-home-as-told-by-an-expert-2804" target="_blank">Click for detail</a>\nYou can also follow this interactive and experiential guide that provides tips to make homes dementia friendly <a href=" https://cloudexpo.hiverlab.com/DFHome/" target="_blank">Click for detail</a>\nThe Housing and Development Board has introduced Enhancement for Active Seniors (EASE) which provides subsidised home modifications for older residents to be able to live at ease in their own homes.']},
#  {'questions': ['Does your loved one with dementia seem to have trouble recognizing or seeing the food?  ',
#    'Does your loved one with dementia squint when looking at the food or ask what it is?',
#    'dementia Having trouble seeing ',
#    'dementia recognising food',
#    'dementia food seeing',
#    'dementia food looking',
#    'dementia food asking'],
#   'answers': ['Has this been evaluated by a doctor? If not, kindly consult your doctor first.\nHandling difficulties recognizing food:\n• Choose a plate that is of a contrasting colour to the food (so they can see it more clearly)\n• Put the drink in their hand if they are struggling to see it\nHandling difficulties eating:\n• Change the consistency of food and drinks (for example serving it in liquid or puree form). Only do this following advice from a healthcare professional\n• Give the person enough time to eat']},
#  {'questions': ['Which specialties can diagnose dementia?',
#    'Who can diagnose dementia',
#    'Where can I visit to get a diagnosis of dementia',
#    'Where to go to get an assessment for dementia',
#    'Which hospital can diagnose dementia',
#    'Which clinic can diagnose dementia',
#    'Who are qualified to perform assessment for dementia',
#    'Who are the specialists that can diagnose dementia',
#    'Can I visit general practitioners to get dementia diagnosis',
#    'Can I visit polyclinics to get dementia diagnosis'],
#   'answers': ['There are generally 3 groups of specialists that they may refer you to for a diagnosis:\n1) Neurologists: Doctors who specialize in disorders of the brain and nervous system\n2) Geriatricians: Doctors who have additional training in treating older adults, especially those 65 and up\n3) Geriatric psychiatrists: Doctors who focus on prevention, evaluation, diagnosis and treatment of mental health disorders in the elderly\n\nYou may obtain a diagnosis by contacting the memory clinic at one of the following hospitals: A polyclinic or a CHAS GP referral is required for subsidised fees\n\n1) Tan Tock Seng Hospital - Geriatric Medicine Clinic [basement 1]\n11 Jalan Tan Tock Seng Singapore 308433\nTel: 6359 6100, Fax: 6359 6101\n\n2) Institute of Mental Health - Psychogeriatric Clinic\n10 Buangkok View Singapore 539747\nTel: 6389 2200, Fax: 6385 1075\n\n3) National University Hospital - Neuroscience Clinic\n5b Lower Kent Ridge Road Singapore 119074\nTel: 6779 5555, Fax: 6779 5678\n\n4) Changi General Hospital - Geriatric Clinic\n2 Simei Street 3 Singapore 529889\nTel: 6850 3510, Fax: 6787 2141\n\n5) Singapore General Hospital - Department of Neurology\nOutram Road Singapore 169036\nTel: 6321 4377, Fax: 6220 3321\nEmail: <a href="appointments@sgh.com.sg" target="_blank">Click for detail</a>\n\n6) NNI @ TTSH Campus - Neuroscience Clinic, Level 1\nNational Neuroscience Institute\n11 Jalan Tan Tock Seng Singapore 308433\nTel: (65) 6357 7095, Fax: (65) 6357 7103\nEmail: <a href="appointments@nni.com.sg" target="_blank">Click for detail</a>\n\n7) Ng Teng Fong Hospital - Geriatric Medicine\na. Jurong East Street 21 Singapore 609606\nTel: 6716 2000 (24 hours), Tel: 6716 2222 (appointment)\n\nb. General practitioners (GPs) and Polyclinics who are certified to support and provide mental health assessment and diagnosis. \nYou may also approach Community Outreach Teams (CREST) and Community Intervention Teams for screening,\nintervention, and caregiver support.\nVisit <a href="www.aic.buzz/mindmatters-directory" target="_blank">Click for detail</a>for the listing of services']},
#  {'questions': ['What counselling services are available for caregivers? ',
#    'Counselling services for caregivers',
#    'Who can provide counselling services for caregivers',
#    "Dementia Singapore's Dementia Helpline",
#    'What are the available counseling services',
#    'Is there anyone who can provide counseling for me',
#    'Who can I go to receive counseling?',
#    'Where can I look for counselors to provide me with counseling services',
#    'Counseling services',
#    'Counseling for caregivers who are taking care of dementia patients'],
#   'answers': ['Below is the list of helplines available:\nImage for Helpline\n- You can access Dementia Singapore Helpline through the Care Buddy App.\n- Caregivers can also look for external counselling services through this link: <a href="https://sacsingapore.org/registry/find-a-counsellor/wpbdp_category/grieflossdepression/" target="_blank">Click for detail</a>']},
#  {'questions': ['Does your loved one with dementia need help with washing/bathing?',
#    'Refusing to be washed',
#    'Refusing to be bathed',
#    'refuse shower',
#    'refuse bath'],
#   'answers': ["Don't make it an issue and re-visit this at a later time\nUnderstand why:\n• Try to work out why your loved one with dementia is refusing to wash. For example, do they think they have already had a bath or shower, or have they forgotten the steps needed to wash themselves?\n• Think about the timing of your request, or the way you phrase it. A person may refuse to wash when you suggest they should, but may decide to wash themselves later in the day – try to be flexible\n• Check if there may be physical problems which are making washing difficult.\nTry alternatives:\n• Try a sponge bath at least twice a week, if they refuse a bath or shower. You can wash them with a wet sponge or cloth, but without them getting into a bath or under a running shower\n• Persuade your loved one to wash by giving them a reason – such as if they are going out or expecting visitors"]},
#  {'questions': ['Does your loved one with dementia have involuntary movement?',
#    'dementia involuntary movement',
#    'dementia involuntary'],
#   'answers': ['- Consult with a doctor regarding the need to change medications. You may contact a telemedicine provider through the CareBuddy app.Try new approaches to getting closer to the person.\n']},
#  {'questions': ['What are some financial schemes that I can tap into?',
#    'Financial schemes for caregiving or dementia patients',
#    'What are some available financial assistance?',
#    'What are some financial schemes that I can apply if I am currently having low income?',
#    'I am having financial difficulty, how can I get help?',
#    'Financial assistance for caregiving or dementia patients',
#    'What are some grants or funds that I can apply for financial assistance?',
#    'Grants or funds or financial support for caregiving or dementia patients',
#    'Mobility assistance ',
#    'Daily activities assistance',
#    'Assistance for individuals or family with low incomes'],
#   'answers': ['Please use the following link to learn more about various financial schemes for caregivers: <a href="https://www.aic.sg/financial-assistance" target="_blank">Click for detail</a>']},
#  {'questions': ['Does your loved one with dementia suffer from any signs of infection?',
#    'dementia sign of infection',
#    'dementia suffer from',
#    'showing signs of infection',
#    'fever',
#    'chills',
#    'shortness of breath'],
#   'answers': ['If you suspect that your loved one with dementia has an infection, consult a doctor for testing and potential treatment.\nYou can read more about how to prevent Urinary Tract Infections here. <a href=" https://www.alzheimers.org.uk/get-support/daily-living/tips-to-prevent-UTIs#content-start " target="_blank">Click for detail</a>\nYou may contact a telemedicine provider through the CareBuddy app.']},
#  {'questions': ['What should I do if I find my loved one with dementia missing?',
#    'Dementia patient is missing',
#    'What should I do if I find my dementia patient missing',
#    'What can I do if my dementia patient disappear or cannot be found',
#    'What should I do if I am unable to locate my patient with dementia',
#    'What to do if my dementia patient is lost',
#    'What should I do if I cannot find my dementia patient',
#    'Where to search for dementia patient when he or she is missing?',
#    'What should I do if my dementia patient tends to go missing?',
#    'My dementia patient went missing, what should I do?',
#    'is missing',
#    'is lost'],
#   'answers': ['1. Preparing for the future\n   • Observe movements and behaviors of your loved one to get a sense of his/her daily routines\n   •  Prepare all the relevant info for quick and easy access\n   • Download the Dementia Friends app. Which will allow you to quickly report your loved one missing \n\n2. First 15 min\n   • Try searching for your loved one in their favourite hangout areas\n   • Ask your neighbor if they have seen your family member\n   • Send a search party to look for them (if you have enough family members and neighbours)\n   •  Bring along the filled in info form\n\n3. First hour\n   • If you are still unable to locate your loved one, or they have been missing for some time, call 999 or got to your nearest Neighbourhood Police Post to make a police report\n\n4. After person with dementia is found\n   • Ensure that your loved one is physically unhurt\n   • Reassure your loved one that he/she is safe\n   • Ensure that all his/her belongings are still on them\n   • Contact all the previous persons you’ve asked for help to inform them\n   • Close the case on the Dementia Friends app\n\n* CARA mobile application - It is a membership programme offered by DSG which provides a unique identifier for each member living with dementia that can help to locate them if lost. \n* Care Buddy application - It can help you estimate the location of your loved with help of the wearable sensors.\n']},
#  {'questions': ['Does your loved one have difficulty cooking meals?',
#    'Difficulty cooking meal',
#    'difficult cooking meal',
#    'difficult cook meals'],
#   'answers': ['•  Arrange for meal delivery services and housekeeping services.\n•  Write reminders and stick them on places they will look at (fridge, bedroom, living room, etc.). \n•  Large and easy-to-read clocks and calendars will help your loved one to orient themselves to the time and date. \n•  Remove hazards from the house such as faulty kitchen appliances, clutter, fire hazards\n•  Use technology in the form of monitoring systems to help track your loved one’s mobility in the house. \nAgency for Integrated Care provides low-cost meal delivery services like Bethesda Care Services <a href="https://bethesdacare.sg/" target="_blank">Click for detail</a> and Meals on Wheels <a href="https://www.aic.sg/care-services/meals-on-wheels" target="_blank">Click for detail</a>. These services might require a referral from a hospital or polyclinic. Estimated cost of Meals on Wheels delivery service: $4.80-$6.96 per meal before subsidies.']},
#  {'questions': ['Is your loved one with dementia still able to sense hot or cold objects? ',
#    'Unable to sense temperature',
#    'hot or cold objects'],
#   'answers': ['Has this been evaluated by a doctor? If not, kindly consult your doctor first.\nBe aware of potential harm:\n• Be careful of giving your loved one hot food or drinks that could burn their mouth and make eating uncomfortable.']},
#  {'questions': ['Does your loved one with dementia get enough sunlight',
#    'dementia getting sunlight',
#    'dementia get enough sunlight'],
#   'answers': ['Bright light therapy\nTake outside or use bright light therapy. Sunshine can improve the temperament of an Alzheimer’s patient. Poor lighting can add to confusion and create behavioural problems like paranoia. Sunlight gives you natural Vitamin D. Let the sunshine in. Bright light therapy consists of regular exposure to a light anywhere from five to 30 times brighter than typical office lights. The light is placed in a box with a screen that diffuses it. The person receiving bright light therapy is asked to sit in front of the light source for a set amount of time each day. You may contact a telemedicine provider through the CareBuddy app.']},
#  {'questions': ['My loved one with dementia is showing erratic behaviour, what can I do?',
#    'What should I do if my loved one with dementia is showing erratic behaviour?',
#    'What can I do if my dementia patient is showing violent behavior?',
#    'What should I do if my dementia patient is showing shouting / wailing / agitated behaviour?',
#    'What should I do if my patient with dementia is showing sexual disinhibition? ',
#    'What should I do if my dementia patient is showing some unpredictable or inappropriate behavior?',
#    'What to do if my patient with dementia has violent and agitated behavior?',
#    'How to deal with dementia patient when he or she is displaying erratic or inappropriate behavior',
#    'What should I do if my loved one with dementia cannot sleep at night',
#    'Dementia patient is showing erratic / unpredictable / unusual / inappropriate behaviour',
#    'sexual disinhibited behaviour'],
#   'answers': ['Use the Care Buddy app to learn how to manage specific behaviours of your loved one']},
#  {'questions': ['What should I do if my loved one with dementia cannot sleep at night',
#    'Does your loved one with dementia often have trouble falling asleep at night?',
#    'Is your loved one with dementia sleeping or tired during much of the day?',
#    'Does your loved one with dementia have to get up often to urinate during the night?',
#    'Does your loved one with dementia get enough sunlight? ',
#    'Does your loved one with dementia drink caffeine fluid?',
#    'Is your loved one with dementia having emotional issues?',
#    'Is your loved one with dementia’s room conducive for sleep (e.g. too much light)?',
#    'Does your loved one with dementia pass urine properly?',
#    'Facing sleeping problems',
#    'Feeling sleepy or tired during the day',
#    'Urinate in night',
#    'Drinking caffeine'],
#   'answers': ['Has this been evaluated by a doctor? If not, kindly consult your doctor first.\n\nYou may contact a telemedicine provider through the CareBuddy app. \n\nModify environment and adjust living preference\n• Understand your loved one’s sleep preferences and accommodate\n• Try encouraging your family member to get up a little earlier each day\n• Engage your loved one in physical activities such as gardening, walking and helping with housework\n• Avoid caffeine and switch to de-caffeinated drinks.\n\nWhat should you do\n• Ensure your loved one is exposed to sunlight before mid-afternoon\n• By providing adequate fluids to your family member, you decrease the risks of nighttime leg cramps and other discomforts\n• Serve the last meal of the day in the early evening and watch portion sizes\n• Limit the news because stories about accidents and bombings may cause your loved one with dementia to obsess\n• Make sure the mattress is comfortable and the bedding is inviting\n• Wind down at the end of the day with simple tasks\n• Build excitement for the next day\n• Make bedtime a pleasant experience\n• Check out things from your loved one’s point of view\n• Provide a favourite soothing and familiar classical piece or a lullaby\n• Tell a favourite story from your loved one’s childhood or recite a popular family prayer\n• Install rope lightning on baseboards or small night lights from your loved one’s room to the bathroom for guidance\n\nUnderstand why:\n• Consult the doctor to find out whether it is related to any medication your loved one is taking. ']},
#  {'questions': ['What is dementia? ',
#    'Define dementia',
#    'What is dementia',
#    'Dementia is what',
#    'Meaning of dementia',
#    'What is the definition of dementia?',
#    'What does having dementia mean?',
#    'Dementia',
#    'What dementia means?',
#    'What dementia is'],
#   'answers': ['Dementia is a condition that causes progressive intellectual decline leading to increasing difficulties in coping with everyday activities. It is characterised by a progressive worsening of memory and intellect (cognitive abilities), orientation, or personality, that is caused by the diseases that affect the brain. It is not part of normal ageing but risks increase with age.']},
#  {'questions': ['How long is the process to get a diagnosis and assessment for dementia?',
#    'How long does one need to get a diagnosis and assessment for dementia',
#    'Time needed to get a diagnosis for dementia',
#    'Time needed to get an assessment for dementia',
#    'Diagnosis for dementia needs to wait for how long',
#    'Assessment for dementia will take how long',
#    'How long will it take to complete a dementia diagnosis',
#    'How long will it take to do a dementia assessment',
#    'How many days/months one needs to wait for an assessment for dementia to finish',
#    'How long is the process to get diagnosed or assessed for dementia'],
#   'answers': ["• Dementia diagnosis can take a long time. To ensure that you have an accurate diagnosis, you may be required to take additional tests, or be referred to a memory clinic or a specialist.\n• Why may that happen?: One reason is that there is no one specific test that can diagnose dementia. If your doctor suspects dementia after your initial assessment, but can't make a definitive conclusion, you will most likely undergo a number of physical and cognitive exams. These exams can determine if you are showing signs that line up with the symptoms of dementia.\n• Once your doctor has a combination of test results, along with your detailed medical history, they should have the evidence needed to give you an official diagnosis."]},
#  {'questions': ['Does your loved one with dementia have a lack of appetite?',
#    'Has your loved one with dementia lost weight recently?',
#    'Do their clothes fit looser than they used to?',
#    'Is your loved one with dementia unable to smell or taste strong stimulants like mint, fish, or citrus?',
#    'Having a lack of appetite',
#    'dementia lack of appetite',
#    'dementia lost weight',
#    'dementia eating difficulty',
#    'dementia unable to smell or taste'],
#   'answers': ['Has this been evaluated by a doctor? If not, kindly consult your doctor first.\nHave patience:\n• Remember that your loved one with dementia does not need a special diet\n• Try not to overload the plate with too much food – small and regular portions often work best. Consider serving half portions to keep hot food from going cold and losing its appeal\n• Give your loved one gentle reminders to eat, and remind them what the food is\n• Look for non-verbal clues such as body language and eye contact as a means of communication\n• Keep calm and try not to rush your loved one with dementia. It’s important they don’t feel hurried and they are given enough time to eat\n• If your loved one with dementia is distressed, don’t put pressure on them. Wait until they are calm and less anxious before offering food and drink\n• Don’t assume your loved one with dementia has finished because they’ve stopped eating \n• While eating a balanced diet is recommended, sometimes it is more important to make sure they are eating enough, even if that means eating unhealthy foods\n• Help them maintain as much independence as possible\nStimulate their appetite:\n• Give your loved one food they like. However, remember that a person’s food preferences can change as their dementia progresses\n• Don’t stop your loved one from eating dessert if they haven’t eaten their savoury meal. They may prefer the taste of the dessert.\n• Try different types of food and drink with varying temperatures and textures.\n• Make food look and smell appealing. Use different tastes, colours and smells. The aroma of cooking can stimulate someone’s appetite.\n• Remember your loved one – think about what they like and don’t like, and bear in mind their life history including past routines.']},
#  {'questions': ['How to prepare nutritious meals for my loved one with dementia?',
#    'What meal or food should I prepare for a dementia patient?',
#    'What diet should a patient with dementia follow?',
#    'What can my dementia patient eat?',
#    'How to ensure my loved one with dementia eat well?',
#    'Meal / food / diet for dementia patients',
#    'What food should I cook for a dementia patient?',
#    'How to prepare or cook meals or food that are healthy for dementia patients?',
#    'Is there any guide for what a dementia patient can eat?',
#    'Recommended diet for patients with dementia'],
#   'answers': ['Institutions and organisations around the world have developed booklets and guides to support care partners of persons living with dementia, by addressing matters related to eating, diets and nutrition. Here are some of these booklets and guides:\n1. The Alzheimer’s Disease International published a report in 2014 titled Nutrition and Dementia , which investigated how a healthy diet and the right nutrition can improve the lives of persons living with dementia.\n2. The Alzheimer Society of Ireland developed a booklet titled Eating Well with Dementia which provides information to support family caregivers.\n3. The Ministry of Health of Israel has also created a guide titled Eating and Living With Dignity for care professionals and family caregivers of persons with dementia. This guide provides information, tips, and recommendations addressing the following in persons with dementia.\nCheck out the recipes from the Care. Cook. Inspire cookbook.\nVisit <a href="www.aic.buzz/cookbook-care-cook-inspire" target="_blank">Click for detail</a>']},
#  {'questions': ['Are you grieving when your loved one passes away?',
#    'Are you experiencing extreme emotions after your loved one has passed away?',
#    'Are you experiencing sadness, anger, loneliness, or other painful emotions after your loved one has passed away?',
#    ' Are you feeling depressed or antagonised after your loved one has passed away?',
#    'Are you concerned with how you are expressing your grief?',
#    'Are you concerned that you are not experiencing significant distress when grieving?',
#    'Are you concerned about the time frame you should be grieving for?',
#    'Are concerned that you are experiencing extreme emotion after your loved one has passed away?',
#    'Do you feel the need to consult a doctor due to the feelings you are experiencing after a loved one has passed away?',
#    'Do you feel the desire to share your feelings because your loved one has passed away?',
#    'Are you concerned that you feel anger after your loved one has passed away?',
#    'Are you concerned that you feel guilt after your loved one has passed away?',
#    'Are you concerned that you feel sadness after your loved one has passed away?',
#    'Are you concerned that you find yourself in denial after your loved one has passed away?',
#    " Are you concerned that you still feel intense emotions of grief even after 12 months of your loved one's passing?",
#    "Do you find yourself still grieving even after 12 months of your loved one's passing?",
#    'Grieving process',
#    'grief',
#    'post-loss grief',
#    'bereavement',
#    'death',
#    'passing away',
#    'loss'],
#   'answers': [' Grief hurts, but it can be helpful. Grieving often involves sadness, anger, loneliness, and other painful emotions. But it can help you come to terms with loss and move forward in life, while still cherishing memories of your loved one.\n Everyone grieves differently. Some people need to express their grief, while others prefer to process in silence.\n Grief does not have a set time frame - It can last for weeks, months, or years. \n It may come and go around holidays, anniversaries, and major life events, or it might always be in the background. However, grief does tend to lessen in intensity over time.\n Not everyone experiences significant distress. People may respond to a loss with resilience or relief. \n Relief is normal - Feeling this way does not mean that you don’t care, or that you love the person any less. It is a natural reaction after a stressful and overwhelming time in your life.\n There are common behaviours that one experiences while grieving and it is perfectly normal to go though some or all of these in any order or any number of times:\n• Denial: Attempting to normalise problematic behaviours instead of trying to manage them.\n• Anger: Manifesting as frustration directed at your loved one or resenting responsibilities.\n• Guilt: Placing unrealistic expectations on yourself and feeling you are not doing enough.\n• Sadness: Finding yourself overwhelmed with feelings of sadness or withdrawing from social activities and withholding your emotions.  \n• Acceptance: Coming to terms with how you have been affected and how the condition has affected your loved one and being able to ask for help.\n Do not hesitate to see your doctor or visit a counsellor if you continue to experience five or more of these symptoms 12 months after your loved one has passed on:\n• You feel that your grief is making you unhealthy or sick.\n• You feel that you have been grieving for much longer than you want to.\n• You keep thinking about harming yourself or ending your life.\n• You are worried that you might hurt others.\n• You are hallucinating about things that aren’t really there.\n• Your behaviour or routine suddenly changes.\n• You have felt hopeless and unable to cope with life for more than two weeks at a stretch.\n• You cannot function at home, work or school.\n• You just cannot get over a feeling of guilt.\n• Your speech functions and body movements have become slow and tired.\n\n Some useful tips on how to cope\n It’s okay to seek help. Support from family and friends can prevent grief from growing out of control. \n Although grief will improve over time for most, this isn’t always the case. Moving on doesn’t mean forgetting. You can continue to live your life, have new experiences, and form new relationships, while continuing to love the person you lost.\n The goal of grieving isn’t to forget, but rather to figure out how you would like to remember, while moving forward.\n Here are some healthy ways to help you cope with grief (Dementia Hub):\n• Get enough rest and sleep: If you cannot sleep well at night, take naps, have some quiet time, and read a book or listen to music.\n• Carry on with your usual activities as much as possible: They will keep you occupied and engaged during this period of grief.\n• Surround yourself with loved ones: Share memories about the deceased. Do not be afraid to laugh at funny moments that you have shared.\n• Avoid quick fixes: It may be tempting to use alcohol, over-eating, or other unhelpful coping mechanisms as a method of dealing with grief. Although they may seem to help for a short while, they will actually make life more difficult in the long term.\n• Try to be open to accept support from others.\n• Take comfort in a support group or in your faith: Attending support group sessions can help you communicate with others in the same situation. Prayer and meditation can help you feel better.\n• Get creative: Write a poem or create a painting to express your feelings. You may be  ...
#  {'questions': ['Are you having any financial problems?',
#    'Are you facing any monetary problems?',
#    'Are you having any money-related problems?',
#    'Are you facing any challenges with your finances?',
#    'Are you having any problems concerning money?',
#    'Facing financial problems'],
#   'answers': ['Please use the following link to learn more about various financial schemes for caregivers:<a href="https://www.aic.sg/financial-assistance" target="_blank">Click for detail</a>']},
#  {'questions': ['Are there any stay-in care facilities available? (e.g., nursing home) How to apply for them? Any subsidy?',
#    'Are there any stay-in care facilities available for people with dementia?',
#    'Are there any stay-in care facilities available for PWD?',
#    'How to apply for stay-in-care facilities for PWD?',
#    'Any subsidy for patients to apply for stay-in facilities?',
#    'Stay-in facilities available for people with dementia',
#    'Nursing home for dementia patients',
#    'Where to apply for stay-in facilities?',
#    'Stay-in-care services or facilities available for people with dementia',
#    'Dementia nursing home or stay in care facilities'],
#   'answers': ['- Nursing Homes are long-term residential care facilities that provide assistance to residents who need help in most of their activities of daily living and/or have daily nursing care needs. In addition, there are selected nursing homes with specific dementia and/or psychiatric facilities that cater to residents who need specialised care and support. \n- Caregivers can also tap on nursing homes for respite care if they need short-term care options for several days to a few weeks for their loved ones, e.g. when your Foreign Domestic Worker goes on home leave. \n- The basic cost varies between $2,000 and $3,600 a month to stay in a nursing home (before MOH subsidy), depending on the level of care required. Additional charges include one-time refundable deposit and administrative charges. Other charges which are not covered by the basic cost may apply. If you need more information or want help paying for the service, please speak to your service provider or the Medical Social Worker.\n- Other stay in care facilities include:\n• Community hospitals - provides short-term care as patients recover after being discharged from acute hospitals (support may be given for a few weeks)\n• Shelter and senior group home - for person with dementia who can move on their own but do not have family or caregiver to look after them. Subsidies can be obtained by speaking to the provider or accessing a financial help scheme.']},
#  {'questions': [' Is your loved one with dementia trying to communicate discomfort? ',
#    'dementia communicate discomfort',
#    'dementia communication discomfort'],
# ...
#    'How can I communicate better with my patient with dementia?',
#    'What should I do to better communicate with my loved one with dementia?',
#    'What are the things to take note when I talk to the patient with dementia?',
#    'Tips or guides for communicating with patient with dementia',
#    'What can I do to improve communication with a dementia patient',
#    'How can I improve communication with my loved one with dementia',
#    'Ways to communicate better with a dementia patient',
#    'What are the things to take note when I am in conversation with my loved one with dementia?',
#    'I cannot communicate with my loved one'],
#   'answers': ["Has this been evaluated by a doctor? If not, kindly consult your doctor first.\n\nVerbal communication:\n• Approach them with care: Knock on the door or ask for permission before you enter\n• Always introduce yourself to them: Speak directly to your loved ones, approach them from the front, so they're aware of your presence\n• Treat them with dignity and respect: Consider bending down to talk to them when they are seated, avoid facing away, keep eye contact, and offer comfort and reassurance\n• Simplify what you say: Speak slowly and clearly, avoid long conversations that require thinking, and ask questions that can be answered with a yes or no\n• Ensure that the physical space is comfortable and quiet: Engage in one-on-one conversations in a surrounding with minimal distractions\n• Optimise their vision and hearing: Ensure that their glasses are being worn properly and that the lighting is good; their hearing aids are in working condition, and their dentures are put on to produce clearer speech\n• Even if you don’t think youur loved one can follow what you’re saying, continue talking to them clearly. They may still feel a certain way even if they don’t fully understand what you’re saying\n\nNon-verbal communication:\n• Sight: Give visual cues to provide context, such as pointing or touching the item you are referring to; if you can't understand what your loved one saying, ask them to point or gesture instead; take note of their body language, and be aware of your own body language\n     • Keep eye contact when communicating\n     • Non-verbal communication (such as gestures, facial expressions and body language) can help\n     • Smile\n• Hearing: Music can trigger memories, improve mood and encourage engagement; try to understand your loved one's music preference\n• Smell: Scent the room with essential oils of lavender and lemon; they have been shown to reduce anxiety and agitation\n• Touch: don't underestimate the power of a loving touch (hold your loved one's hands or give them a light hand massage), gently touch your loved one to maintain attention if they are easily distracted, and use appropriate physical contact (such as holding hands) to let youur loved one know you are there and offer reassurance, video with tips--https://www.aic.sg/body-mind/namaste-care\n• Consider responding to them how they respond to you (‘mirroring’ them).\nBe patient:\n• Take time to listen to what your loved one feels, thinks, or needs, give them time to respond, and don't interrupt or finish sentences unless they ask for help to complete a sentence"]},
#  {'questions': ['Does your loved one with dementia get up at night repeatedly?',
#    'Does your loved one with dementia often have trouble falling asleep at night?',
#    'Is your loved one with dementia sleeping or tired during much of the day?',
#    'Does your loved one with dementia have to get up often to urinate during the night?',
#    'Does your loved one with dementia get enough sunlight? E.g., at least 30 mins',
#    'Does your loved one with dementia drink caffeine fluid?',
#    'Is your loved one with dementia having emotional issues (e.g., stressed, anxious)?',
#    'Is the room conducive for sleep (e.g., too much light)?',
#    'Is she/he passing urine properly?',
#    'Facing sleeping problems',
#    'Feeling sleepy or tired during the day',
#    'Urinate in night',
#    'Drinking caffeine'],
#   'answers': ['Has this been evaluated by a doctor? If not, kindly consult your doctor first.\nYou may contact a telemedicine provider through the CareBuddy app. \nModify environment and adjust living preference:\n• Understand your loved one’s sleep preferences and accommodate\n• Try encouraging your family member to get up a little earlier each day\n• Engage your loved one in physical activities such as gardening, walking and helping with housework\n• Avoid caffeine and switch to de-caffeinated drinks.\nWhat should you do:\n• Ensure your loved one is exposed to sunlight before mid-afternoon\n• By providing adequate fluids to your family member, you decrease the risks of nighttime leg cramps and other discomforts\n• Serve the last meal of the day in the early evening and watch portion sizes\n• Limit the news because stories about accidents and bombings may cause your loved one with dementia to obsess\n• Make sure the mattress is comfortable and the bedding is inviting\n• Wind down at the end of the day with simple tasks\n• Build excitement for the next day\n• Make bedtime a pleasant experience\n• Check out things from your loved one’s point of view\n• Provide a favourite soothing and familiar classical piece or a lullaby\n• Tell a favorite story from your loved one’s childhood or recite a popular family prayer\n• Install rope lightning on baseboards or small night lights from your loved one’s room to the bathroom for guidance\nUnderstand why:\n• Consult the doctor to find out whether it is related to any medication your loved one is taking.']},
#  {'questions': ['What should I do if my loved one with dementia keeps asking/saying repetitive things?',
#    'What should I do if my dementia patient keeps asking repetitive things',
#    'What can I do if the patient with dementia keeps repeating the same questions',
#    'What should I do if the patient keeps repeating the same things or the same lines',
#    'What to do if my loved one is always saying repetitive things',
#    'Dementia patients keep repeating the same questions ',
#    'Are there any tips for how to manage the dementia patient if he or she keeps repeating a question',
#    'What to do if the patient with dementia keeps saying the same things ',
#    'What should I do when the dementia patient ask the same question over and over again',
#    'How should I react to my loved one if he or she keeps repeating the same thing or same question'],
#   'answers': ['Try things that can stimulate your loved one\n• It is important to keep trying things that can stimulate your loved one. \n• If they are losing many of their cognitive skills, try music, encourage physical activity, and get them out of doors for sensory stimulation, natural vitamin D and that spiritual connection that happens for all of us in nature.                                                                                                                                                                             \n• Try to regulate nigh sleep pattern and avoid sleep in daytime.\n• It’s often helpful to find something your loved one used to enjoy doing before she developed Alzheimer’s disease that you might be able to still do with them. Even talking to them during short walks might be enjoyable.\n\nOther tips\n•  It’s best to not have a big discussion with your loved one when you’re trying to get them to do something physically active. You might just say, “Come on Dad, let’s go for a walk around the block.”       \n• You could also ask for their help with something that will require them to get up and move. The more calm and natural you are in making these requests, the less likely your loved one will refuse.       \n• Often times you need to try several different ways to approach a problem—what works one time may not work the next. Your loved one may no longer be able to take initiative, but you may find they respond to your requests to do something with you.                          ']},
#  {'questions': ['What are the signs and symptoms of dementia?',
#    'Signs and symptoms of dementia',
#    'What are the signs of dementia',
#    'What are the symptoms of dementia',
#    'What are some signs and symptoms of dementia',
#    'Signs and symptoms',
#    'Symptoms of dementia patients',
#    'Signs of PWD',
#    'How are patients with dementia like',
#    'How are PWDs like'],
#   'answers': ['The signs and symptoms include physical and behavioural. Please go one by one more detail.']},
#  {'questions': ['Are there any subsidies available for seeing a doctor/medication?',
#    'Subsidies for seeing a doctor',
#    'Subsidies for medication',
#    'Subsidies for visiting a doctor for dementia treatment',
#    'Does the government provide any subsidy for dementia medication and treatment',
#    'Subsidies for dementia treatment',
#    'What are the available subsidies for dementia treatment',
#    'Are there any subsidies for treating dementia',
#    'Are there any subsidies for buying dementia medication',
#    'Subsidy for visiting a GP or polyclinic or hospital',
#    'subsidies for dementia care',
#    'government subsidies for dementia care'],
#   'answers': ['• Government subsidies are available for dementia care treatments at the Public Healthcare Institutions (PHIs). \n• Singaporeans who need a hospital stay can enjoy government subsidies of up to 80% in subsidised wards. MediShielf Life and MediSave can also be used to pay fr their bills                                                                                                                                                                                                                                                                           \n• Mediation for dementia, incuded in the Standard Drug List (SDL) or Medication Assistance Fund (MAF) can be subsidised up to 75% by PHIs \n• Pioneers and Merdeka Generation seniors are further entitled to an additional 50% or 25% off their post-subsidy bills for their medications respectively.\n• For patients who visit GP clinics, they also receive subsidies via the Community Health Assist Scheme (CHAS) which helps defray the cost of treatment and medication, including for 20 chronic diseases, such as dementia.                                                                                                                                                               ']},
#  {'questions': ['My loved one with dementia has a fall, what can I do?',
#    'What should I do if my dementia patient has a fall?',
#    'What can I do if my dementia patient fell?',
#    'My patient with dementia fell just now, what should I do?',
#    'How to improve the motor skills of a dementia patient?',
#    'My dementia patient fell down at home, what should I do?',
#    'How to prevent dementia patient from falling down?',
#    'How can I help my dementia patient after he or her had a fall?',
#    'Dementia patient has a fall / fell down',
#    'What to do if the patient with dementia injured himself or herself after a fall?',
#    'fall',
#    'fell',
#    'falling',
#    'your loved one with dementia fall over often',
#    'dementia often fall over'],
#   'answers': ["- Has this been evaluated by a doctor? If not, kindly consult your doctor first.\n- Home modifications for your loved one with dementia that are unsteady on feet \n- Home modifications for motor deficiencies \n        •  Add grab bars, especially in wet and slippery areas, e.g. bathroom    \n        •  Use  non-slip mats or apply non-slip treatments on floors of wet and slippery areas, e.g. bathroom and toilet\n        •  Remove any rugs and wires on the floor\n        •   Move switches to an accessible level\n        •  If you stay in a multi-storey house, move your loved one to a room on the ground floor\n- Home Modifications for Vision Deficiencies:\n        •  Use different colours for the floor, walls, and doors to help a person living with dementia distinguish between the two\n        •  Use contrasting colours for different surfaces/objects. This will help them tell the difference between items and spaces and is especially useful for those living with visual-spatial impairment.\n        •  Highlight steps and stairs with fluorescent tape for better visibility at night\n- Complex Modifications: \n        •  Widen doorways for easy access into rooms, if your care recipient uses a wheelchair\n        •  Install ramps\n        •  Remove walls          \n- How to prevent fall injuries:\n        • It's very important for people with dementia to keep their bones as healthy as possible. This is because people with dementia are at risk of falls, and bone health makes a big difference to the effect of a fall.\n       • Calcium and vitamin D are important for maintaining strong bones. Please check with your health care provider if you need to take any supplements.\n- You can watch this video where OT Hwan Jing from Dementia Singapore answers questions on how to design a dementia-friendly home https://qanvast.com/sg/articles/how-to-design-a-dementia-friendly-home-as-told-by-an-expert-2804\n- You can also follow this interactive and experiential guide that provides tips to make homes dementia friendly https://cloudexpo.hiverlab.com/DFHome/\n- The Housing and Development Board has introduced Enhancement for Active Seniors (EASE) which provides subsidised home modifications for older residents to be able to live at ease in their own homes. You can get more details here.  https://www.hdb.gov.sg/cs/infoweb/residential/living-in-an-hdb-flat/for-our-seniors/ease"]},
#  {'questions': ['Does your loved one with dementia show signs of blood clot?',
#    'dementia sign of blood',
#    'dementia blood clot'],
#   'answers': ['• Consult a doctor immediately for testing and treatment.\n• You may contact a telemedicine provider through the CareBuddy app.']},
#  {'questions': ['Does your loved one with dementia have difficulty dressing?',
#    'Does your loved one with dementia need help dressing?',
#    'Having difficulty wearing clothes',
#    'difficulty dressing',
#    'need help dressing'],
#   'answers': ['Make things easier:\n• You may have to simplify some choices so that they can make decisions, but try to support them to choose, rather than choosing for them. For example, instead of deciding what your loved one will wear, ask them to choose between two tops that you’ve picked out.\nMake it a positive experience:\n• Be encouraging about the activity – for instance talking about how nice an item of clothing looks.\nRespect their privacy:\n• Make sure another person will not walk in while they are getting dressed.\n• Close blinds or curtains for privacy.']},
#  {'questions': ['What are the psychological impacts of tube feeding? ',
#    'tube feeding impacts',
#    'psychological impacts of tube feeding'],
#   'answers': ['Tube feeding can be a difficult experience for persons with dementia. Feeding tubes may add discomfort to person living with dementia. They may also need to be restrained if there is a tendency to pull out the feeding tube.                                                                                                                                                         \nWays to mitigate emotional distress and improve compliance:                                                    \n1. Seek specialists to get your loved ones to learn how to use the NG tube                                                                          \n2. Get educated on specific feeding methods and processes                                                  \n3. Practice the skills required would make them more comfortable using it                                               \n4. Minimize distruptions while they are feeding and creating a feeding schedule to create familiarity                                                                                                                            \n5. Allow them to gain independence in feeding themselves through the tube ']}]

# %%
len(qn_ans_list)
# Out:
# 139

# %%
# Extract questions that have multiple answers
def extract_multi_answer_qns(qn_ans_list:list[dict]) -> list[dict]:
    final = []
    for qn_ans in qn_ans_list:
        if len(qn_ans['answers']) > 1:
            final.append(qn_ans)
    return final

multi_answer_qns = extract_multi_answer_qns(qn_ans_list)
multi_answer_qns[0]['answers']
# Out:
# ["Ask for help\n• Tell friends and family how you're feeling: be honest about how you're feeling and what the situation is, having a conversation about how to move forward will be beneficial\n• Spread the responsibility, if possible: divide tasks up to other family members so that they can all pitch in. Tasks can include medical responsibilities, finances, bills, groceries, chores, etc. \n• Don’t be afraid to accept help: others feel good about themselves when helping others, so don't feel guilty\n• Look into respite care if necessary \n\nHear from caregiver Paul on his journey to care for his mother who lives with dementia:\nhttps://m.facebook.com/watch/?v=1006218726996702&_rdr\n\nRespite is important for caregivers and you may need to access this unexpectedly. Planning ahead for respite care will help you to better care for yourself and your loved ones. You can pre-enrol for respite care ahead of time under the Go Respite pilot programme by AIC\nhttps://www.aic.sg/caregiving/go-respite-pilot\n\nHere is a list of participating service providers for Go Respite Programme:\nhttps://www.aic.sg/caregiving/Documents/Go%20Respite%20-%20Participating%20Centres%20and%20NHs%20(for%20SSP).pdf\n\nYou can listen and follow this relaxation exercise which may help to reduce your stress and anxiety",
#  '\n\n\n\n\n\n\n\n\n1) If anxious or depressive symptoms do 1) self-care worksheet and 2) caregiver stress worksheet mandated while 3) caregiver identity and journey is optional\n2) If not anxious or depressive symptoms 1) self-care mandated and 2) caregiving identity and journey optional\n\n\nFrequency of doing these worksheets – \na. Mandated for those identified with anxiety or depressive symptoms\nb. Optional for those that do not have anxiety and depressive symptoms\nc. Every 3 months review the worksheets and see if they would like to change']

# %% [markdown]
# # Embedding

# %%
dataEmbedding = DataEmbedding(openai_embedding=OpenAIEmbeddings(),text_splitter=RecursiveCharacterTextSplitter())

sample = dataEmbedding.prepareJson(qn_ans_list)
# Out:
# 100%|██████████| 139/139 [00:48<00:00,  2.86it/s]

# %%
sample
# Out:
# [{'id': '0',
#   'values': [0.017125344103254253,
#    0.000198176511309184,
#    0.023978052939949885,
#    -0.03931629330984183,
#    -0.002725655244727573,
#    0.004409904643074602,
#    -0.018372459550987943,
#    -0.026665138391123343,
#    0.00925694230543996,
#    -0.017588190939129476,
#    -0.007945542316245106,
#    0.006724140219434592,
#    -0.021239539855607493,
#    -0.005898086888457016,
#    0.008800524389372148,
#    -0.022730937492216198,
#    0.03396783808672455,
#    -0.0075212657395852915,
#    -0.011050474958609679,
#    0.023065215245169086,
#    0.026999416144076235,
#    ...],
#   'metadata': {'questions': ['What is Advance Care Planning (ACP)? ',
#     'What is the programme that helps me plan out future health and personal care?',
#     'Which programme helps me plan for future medical care?',
#     'Advance Care Planning (ACP)'],
#    'answers': ["- Advance Care Planning (ACP) is the process of planning for future health and personal care your loved one's ACP document tells you and doctors about the treatment options your loved one prefers, should they be unable to communicate their wishes.  \n- This is about creating a plan that can be used if your loved one is unable to make their own decisions. They can also change it at any time, as long as your loved one retains their mental capacity.\n- Your loved one can do an ACP if they have mental capacity. Mental capacity refers to a person’s ability to make a decision for themselves and is specific to the particular decision that needs to be made. \n- A person is deemed to have mental capacity, when they can still:\n     • Understand the facts involved in making the decision.\n     • Retain the information used in decision making.\n     • Use the information to weigh up the pros, cons, and consequences of their choice; and communicate the decision they have made."]}},
#  {'id': '1',
#   'values': [0.017015572805939298,
#    -0.00046073206342050403,
#    0.03877968007012723,
#    -0.052591268494349856,
#    -0.010256573659493574,
#    0.02621904600316988,
#    0.017832525251197474,
#    0.013811590286867795,
#    -0.04881286669465983,
#    -0.0024524508287154904,
#    -0.006797293734109538,
#    0.021202450828258414,
#    -0.018087823123171302,
#    0.021623691758221677,
#    0.0036635180366985805,
#    -0.0023343758888905003,
#    0.050523359829181234,
#    0.01540719919273646,
#    0.019568547800387227,
#    -0.016045443872671025,
#    -0.02424049028934048,
#    0.005472938584382419,
#    0.008731171575285456,
#    0.00959918284988033,
#    0.003925197796678203,
#    -0.008846055803938194,
#    0.002316824183475364,
#    -0.008609905924288213,
#    -0.0014567909673796706,
#    -0.00026048315597853515,
#    0.012815931007608592,
#    -0.004841077189437525,
#    -0.01420730180216271,
#    -0.04786826717605991,
#    0.011111820226754276,
#    0.0014081248221761923,
#    0.003081120813996196,
#    -0.009975747304173983,
#    0.012432984199647851,
#    -0.0427878466018324,
#    0.004723002249612534,
#    0.013020168187600552,
#    0.005182537767239613,
#    -0.020819504020297676,
#    -0.00883329109660402,
#    0.01793464477251604,
#    -0.049374521267944185,
#    -0.013632882521544185,
#    -0.030380392748175482,
#    0.003749680975357489,
#    -0.0015628988776635493,
#    0.016249681052662987,
#    -0.02204493268818494,
#    -0.0032422773395659635,
#    0.0011919197977358592,
#    -0.013581822760884902,
#    -0.005539954229209419,
#    0.03540975263042112,
#    0.017360225491897512,
#    -0.009726831785867245,
#    -0.00749297959704789,
#    -0.008712024514284194,
#    0.004984682009592156,
#    0.037350014222248006,
#    0.0011360735046569077,
#    -0.005377201882392235,
#    -0.007614245713706424,
#    -0.0019753638385039216,
#    0.00185250190059797,
#    0.019096248041087265,
#    0.028542252540312334,
#    0.023206535956756168,
#    0.016054757585072642,
#    0.031238924105608606,
#    -0.0012122686508558437,
#    -0.0271164096621201,
#    -0.0175910990309117,
#    -0.0014987321940418252,
#    0.018026395494502648,
#    0.014159937958653982,
#    0.004698641321524892,
#    0.025900139583661497,
#    -0.00716958922296385,
#    0.0045930181614448375,
#    0.006939138099220253,
#    0.030342725394530465,
#    0.010421510273609155,
#    0.01001181866259184,
#    -0.014710460449778036,
#    0.026002562719246478,
#    0.027423679068875044,
#    ...],
#   'metadata': {'questions': ['What are the behavioural symptoms of dementia?',
#     'behavioural symptoms of dementia',
#     'dementia behavioural symptoms',
#     'dementia behavioural'],
#    'answers': ['Some of the behavioural symptoms or behaviours that your loved one may display could be:\n1) physically aggressive symptoms like hitting, kicking, throwing objects, etc\n2) physically non-aggressive symptoms like being restless, fidgety, repetitious movements, etc\n3) verbally aggressive and non-aggressive symptoms like making verbal sexual advances, making strange noises, etc\n4) mood changes\n5) hallucination/delusions\n6) being disoriented in time or space\n7) refusing or avoiding care ']}}]

# %%
pinecone.init(api_key=PINECONE_API_KEY,environment=PINECONE_ENVIRONMENT)
index = pinecone.Index(index_name=INDEX_NAME)
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0001,
#  'namespaces': {'': {'vector_count': 10}},
#  'total_vector_count': 10}

# %%
index.upsert(sample)
# Out:
# {'upserted_count': 139}

# %%
indexer = Indexer(PINECONE_API_KEY=os.getenv('PINECONE_API_KEY'),INDEX_NAME=os.getenv('PINECONE_INDEX_NAME'),PINECONE_ENVIRONMENT=os.getenv('PINECONE_ENVIRONMENT'))
# Out:
# Successfully connected to Pinecone Index:
# {'dimension': 1536,
#  'index_fullness': 0.0001,
#  'namespaces': {'': {'vector_count': 10}},
#  'total_vector_count': 10}

# %%
indexer.upsertQNA(qn_ans_list)
# Out:
# data_batches:  [[{'questions': ['What is Advance Care Planning (ACP)? ', 'What is the programme that helps me plan out future health and personal care?', 'Which programme helps me plan for future medical care?', 'Advance Care Planning (ACP)'], 'answers': ["- Advance Care Planning (ACP) is the process of planning for future health and personal care your loved one's ACP document tells you and doctors about the treatment options your loved one prefers, should they be unable to communicate their wishes.  \n- This is about creating a plan that can be used if your loved one is unable to make their own decisions. They can also change it at any time, as long as your loved one retains their mental capacity.\n- Your loved one can do an ACP if they have mental capacity. Mental capacity refers to a person’s ability to make a decision for themselves and is specific to the particular decision that needs to be made. \n- A person is deemed to have mental capacity, when they can still:\n     • Understand the facts involved in making the decision.\n     • Retain the information used in decision making.\n     • Use the information to weigh up the pros, cons, and consequences of their choice; and communicate the decision they have made."]}, {'questions': ['How can I take care of myself while caring for my loved one with dementia?', 'How can a caregiver take care of himself or herself while caring for dementia patient?', 'What should a caregiver do to better take care of ownself while caring for the loved one with dementia?', 'Self-help or self-care for caregivers who are caring for a patient with dementia', 'Tips and guides for caregiver self-care', 'What can a caregiver do to better take care of himself or herself while caring for the patient?', 'Self-care tips for caregivers', 'What should caregivers do if finding it difficult to spare time or effort for other matters', 'Self-help tips', 'What should a caregiver do to stay healthy while caring for the loved one with dementia?'], 'answers': ['Ask for help\n• Tell friends and family how you\'re feeling: be honest about how you\'re feeling and what the situation is, having a conversation about how to move forward will be beneficial\n• Spread the responsibility, if possible: divide tasks up to other family members so that they can all pitch in. Tasks can include medical responsibilities, finances, bills, groceries, chores, etc. \n• Don’t be afraid to accept help: others feel good about themselves when helping others, so don\'t feel guilty\n• Look into respite care if necessary \n\nHear from caregiver Paul on his journey to care for his mother who lives with dementia:\n\n<a href="https://m.facebook.com/watch/?v=1006218726996702&_rdr" target="_blank">Click for detail</a>\n\nRespite is important for caregivers and you may need to access this unexpectedly. Planning ahead for respite care will help you to better care for yourself and your loved ones. You can pre-enrol for respite care ahead of time under the Go Respite pilot programme by AIC\n\n<a href="https://www.aic.sg/caregiving/go-respite-pilot" target="_blank">Click for detail</a>\n\nHere is a list of participating service providers for Go Respite Programme:\n<a href="https://www.aic.sg/caregiving/Documents/Go%20Respite%20-%20Participating%20Centres%20and%20NHs%20(for%20SSP).pdf\n" target="_blank">Click for detail</a>\n\nYou can listen and follow this relaxation exercise which may help to reduce your stress and anxiety\n\nYou can also refer to some of the worksheets in the CareBuddy app that may help to address your anxiety and depression\n']}, {'questions': ['How to apply for CARA?', 'How to register for CARA?', 'How to join CARA?', 'Who are eligible to join CARA?', 'How to apply for CARA membership?', 'What is CARA?', 'What is CARA membership?', 'How long is the CARA application process?', 'How to register for CARA membership?', 'What will I receive if I apply for CARA?', 'What CARA?'], 'answers': ['- A CARA membership is eligible to Singapore r ...
# 100%|██████████| 10/10 [00:03<00:00,  2.82it/s]
# Upserted 10 rows, upsert_response: {'upserted_count': 10}
# 100%|██████████| 10/10 [00:03<00:00,  2.93it/s]
# Upserted 10 rows, upsert_response: {'upserted_count': 10}
# 100%|██████████| 10/10 [00:03<00:00,  2.91it/s]
# Upserted 10 rows, upsert_response: {'upserted_count': 10}
# 100%|██████████| 10/10 [00:03<00:00,  2.92it/s]
# Upserted 10 rows, upsert_response: {'upserted_count': 10}
# 100%|██████████| 10/10 [00:03<00:00,  3.00it/s]
# Upserted 10 rows, upsert_response: {'upserted_count': 10}
# 100%|██████████| 10/10 [00:03<00:00,  2.82it/s]
# Upserted 10 rows, upsert_response: {'upserted_count': 10}
# 100%|██████████| 10/10 [00:03<00:00,  3.02it/s]
# Upserted 10 rows, upsert_response: {'upserted_count': 10}
# 100%|██████████| 10/10 [00:03<00:00,  2.62it/s]
# Upserted 10 rows, upsert_response: {'upserted_count': 10}
# 100%|██████████| 10/10 [00:03<00:00,  2.94it/s]
# Upserted 10 rows, upsert_response: {'upserted_count': 10}
# 100%|██████████| 10/10 [00:03<00:00,  2.91it/s]
# Upserted 10 rows, upsert_response: {'upserted_count': 10}
#  20%|██        | 2/10 [00:01<00:04,  1.93it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\pineconeInsert.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/stu-kalebnim/Documents/GitHub/Medi-API/pineconeInsert.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> indexer.upsertQNA(qn_ans_list)
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\PineconeUtils\Indexer.py:124, in Indexer.upsertQNA(self, QNA_list, batch_size)
#     121 data_batches = [data[i:i + batch_size] for i in range(0, len(data), batch_size)]
#     122 print('data_batches: ', data_batches)
# --> 124 upsert_responses = []
#     125 for batch in data_batches:
#     126     upsert_response = self.index.upsert(batch)
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\PineconeUtils\Indexer.py:74, in DataEmbedding.prepareJson(self, QNA_list)
#      71     # concat to a single string
#      72     row_text = ','.join(list_of_questions)
# ---> 74     values = self.openai_embedding.embed_query(row_text)
#      75     data.append({
#      76         'id': str(index),
#      77         'values': values,
#      78         'metadata': row
#      79     })
#      80 return data
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\langchain\embeddings\openai.py:511, in OpenAIEmbeddings.embed_query(self, text)
#     502 def embed_query(self, text: str) -> List[float]:
#     503     """Call out to OpenAI's embedding endpoint for embedding query text.
#     504
#     505     Args:
#    (...)
#     509         Embedding for the text.
#     510     """
# --> 511     return self.embed_documents([text])[0]
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\langchain\embeddings\openai.py:483, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     471 """Call out to OpenAI's embedding endpoint for embedding search docs.
#     472
#     473 Args:
#    (...)
#     479     List of embeddings, one for each text.
#     480 """
#     481 # NOTE: to keep things simple, we assume the list may contain texts longer
#     482 #       than the maximum context and use length-safe embedding function.
# --> 483 return self._get_len_safe_embeddings(texts, engine=self.deployment)
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\langchain\embeddings\openai.py:367, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     364     _iter = range(0, len(tokens), _chunk_size)
#     366 for i in _iter:
# --> 367     response = embed_with_retry(
#     368         self,
#     369         input=tokens[i : i + _chunk_size],
#     370         **self._invocation_params,
#     371     )
#     372     batched_embeddings.extend(r["embedding"] for r in response["data"])
#     374 results: List[List[List[float]]] = [[] for _ in range(len(texts))]
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\langchain\embeddings\openai.py:107, in embed_with_retry(embeddings, **kwargs)
#     104     response = embeddings.client.create(**kwargs)
#     105     return _check_response(response, skip_empty=embeddings.skip_empty)
# --> 107 return _embed_with_retry(**kwargs)
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\tenacity\__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\langchain\embeddings\openai.py:104, in embed_with_retry.<locals>._embed_with_retry(**kwargs)
#     102 @retry_decorator
#     103 def _embed_with_retry(**kwargs: Any) -> Any:
# --> 104     response = embeddings.client.create(**kwargs)
#     105     return _check_response(response, skip_empty=embeddings.skip_empty)
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\openai\api_resources\embedding.py:33, in Embedding.create(cls, *args, **kwargs)
#      31 while True:
#      32     try:
# ---> 33         response = super().create(*args, **kwargs)
#      35         # If a user specifies base64, we'll just return the encoded string.
#      36         # This is only for the default case.
#      37         if not user_provided_encoding_format:
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:155, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     129 @classmethod
#     130 def create(
#     131     cls,
#    (...)
#     138     **params,
#     139 ):
#     140     (
#     141         deployment_id,
#     142         engine,
#    (...)
#     152         api_key, api_base, api_type, api_version, organization, **params
#     153     )
# --> 155     response, _, api_key = requestor.request(
#     156         "post",
#     157         url,
#     158         params=params,
#     159         headers=headers,
#     160         stream=stream,
#     161         request_id=request_id,
#     162         request_timeout=request_timeout,
#     163     )
#     165     if stream:
#     166         # must be an iterator
#     167         assert not isinstance(response, OpenAIResponse)
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\openai\api_requestor.py:289, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     278 def request(
#     279     self,
#     280     method,
#    (...)
#     287     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     288 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 289     result = self.request_raw(
#     290         method.lower(),
#     291         url,
#     292         params=params,
#     293         supplied_headers=headers,
#     294         files=files,
#     295         stream=stream,
#     296         request_id=request_id,
#     297         request_timeout=request_timeout,
#     298     )
#     299     resp, got_stream = self._interpret_response(result, stream)
#     300     return resp, got_stream, self.api_key
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\openai\api_requestor.py:606, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     604     _thread_context.session_create_time = time.time()
#     605 try:
# --> 606     result = _thread_context.session.request(
#     607         method,
#     608         abs_url,
#     609         headers=headers,
#     610         data=data,
#     611         files=files,
#     612         stream=stream,
#     613         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     614         proxies=_thread_context.session.proxies,
#     615     )
#     616 except requests.exceptions.Timeout as e:
#     617     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\stu-kalebnim\Documents\GitHub\Medi-API\env\lib\site-packages\urllib3\connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Querer

# %%
class PineconeQuery:
    """Main class to query both text/sentence/images with pinecone"""
    embedding_model:OpenAIEmbeddings = OpenAIEmbeddings(model='text-embedding-ada-002')
    NAMESPACES = ["personal","experience","projects","thoughts"]

    def _initPinecone(self,PINECONE_API_KEY:str,PINECONE_ENVIRONMENT:str,INDEX_NAME:str) -> pinecone.index:
        """Init Pinecone stuff"""

        pinecone.init(api_key=PINECONE_API_KEY,environment=PINECONE_ENVIRONMENT)
        # connect to index
        index:Index = pinecone.Index(INDEX_NAME)
        return index

    def __init__(self,PINECONE_API_KEY:str,PINECONE_ENVIRONMENT:str,INDEX_NAME:str):
        """ Initialize the Pinecone Index from .env file pinecone variables"""
        start_time = time()
        
        # connect to index
        self.index:Index = self._initPinecone(PINECONE_API_KEY,PINECONE_ENVIRONMENT,INDEX_NAME)
        self.embedding_model:OpenAIEmbeddings = self.embedding_model
        self.namespaces:list[str]  = ["personal","experience","projects","thoughts"]
        # Init the namespaces docsearch
        # self.docsearch = Pinecone.from_existing_index(INDEX_NAME, embedding_model) # default namespace
        # self.docsearch_personal = Pinecone.from_existing_index(INDEX_NAME, embedding_model, namespace="personal")
        # self.docsearch_experience = Pinecone.from_existing_index(INDEX_NAME, embedding_model, namespace="experience")
        # self.docsearch_projects = Pinecone.from_existing_index(INDEX_NAME, embedding_model, namespace="projects")
        # self.docsearch_thoughts = Pinecone.from_existing_index(INDEX_NAME, embedding_model, namespace="thoughts")
        print(f'Successfully connected to Pinecone Index:\n{self.index.describe_index_stats()},took {time() - start_time} seconds')


    def _checkValidNamespace(self,namespace:str) -> bool:
        # Check if namespace is valid
        if namespace not in self.namespaces:
            raise Warning(f"Namespace not found, must be one of the following {self.namespaces}. using default namespace= None")
        
        return True
    


    def query(self,query:str,namespace:str=None,top_k:int = 3) -> list[dict]:
        """Select a query and fetch the results

        Raises ValueError if namespace is not one of the following:
            ValueError: Namespace must be one of the following ['personal', 'experience', 'projects', 'thoughts']

        Args:
            query (str): Query to search
            namespace (str): Namespace to search can be one of the following
                >personal experience, projects, thoughts

        Returns:
            list[dict]: List of matched documents, Top 3 relevant documents
            Example matched_docs[
                {'id': '4',
  'score': 0.737784088,
  'values': [],
  'metadata': {'categories': 'personal',
   'isImage': False,
   'text': 'WTH ( Finalist ) Activities: NUS LifeHack 2021 ( Participant ) SUTD What The Hack: Environment 2021 ( Participant ) Appetizer Hackathon 2021 ( Participant ) SPAI Beginner Machine Learning Bootcamp 2021 SPAI Advance Machine Learning Workshop 2021 SEED Code League 2021 ( Participant ) NUS LifeHack 2022 ( Participant ) NTUtion 2022 Hackathon ( Participant ) NUS LifeHack 2023( Participant )'}},
 {'id': '2',
  'score': 0.728767276,
  'values': [],
  'metadata': {'categories': 'personal',
   'isImage': False,
   'text': 'Activities:\nNUS LifeHack 2021 ( Participant )\nSUTD What The Hack: Environment 2021 ( Participant )\nAppetizer Hackathon 2021 ( Participant )\nSPAI Beginner Machine Learning Bootcamp 2021\nSPAI Advance Machine Learning Workshop 2021\nSEED Code League 2021 ( Participant )\nNUS LifeHack 2022 ( Participant )\nNTUtion 2022 Hackathon ( Participant )'}},
 {'id': '3',
  'score': 0.725435615,
  'values': [],
  'metadata': {'categories': 'personal',
   'isImage': False,
   'text': 'NUS LifeHack 2023( Participant )Achievement: Polyfintech100 API Hackthon 2023 ( Champion ) Batey Hackathon 2022 ( Champion Gold ) Polyfintech100 API Hackthon 2023 ( 1st runner up ) Polyfintech 2022 ( 1st Runner-Up) DSAC AI Makerspace Holiday Challenge 2021 ( Champion ) FPG FIT Hack 2021 ( Finalist ) SUTD WTH ( Finalist ) Activities:'}}
   ]
        """

        query_embedding = self.embedding_model.embed_query(query)
        # Get the top 3 results
        results = self.index.query(query_embedding,top_k=top_k,include_metadata=True)
        print('results: ', results)
        
        results_dict = results.to_dict()
        print('results_dict: ', results_dict)
        matched_docs = results_dict["matches"]
        return matched_docs


# Test the class
pineconeQuery = PineconeQuery(PINECONE_API_KEY,PINECONE_ENVIRONMENT,INDEX_NAME)
# Out:
# Successfully connected to Pinecone Index:
# {'dimension': 1536,
#  'index_fullness': 0.0001,
#  'namespaces': {'': {'vector_count': 10}},
#  'total_vector_count': 10},took 0.8778841495513916 seconds

# %%
def parseQnDocs(questions:list[str]) -> str:
    """Format the questions to a single string"""
    final = ""
    for qn in questions:
        final += f"{qn}\n"
    return final
